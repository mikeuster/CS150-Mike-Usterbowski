# %% [markdown]
# #Michael Usterbowski - Markdown Practice

# %% [markdown]
# ### Hi, I'm Michael Usterbowski. I'm interested in coding because I want to learn how programs actually work and how coding can be used in real life, especially in business, analytics, and problem-solving.

# %% [markdown]
# - Attending lectures and class discussions
# - Completing programming assignments
# - Practicing coding in Jupyter Notebook
# - Participating in labs or in-class activities
# - Taking quizzes and exams
# - Using GitHub to submit assignments

# %% [markdown]
# 1. Module 1: Variables and Simple Data Types
# 2. Module 2: Lists and Tuples (Part 1)
# 3. Module 3: If Statements
# 4. Module 4: Loops
# 5. Module 5: Lists and Tuples (Part 2)
# 6. Module 6: Dictionaries
# 7. Module 7: Sets, Functions, and Libraries
# 8. Module 8: Class Datatypes and Exceptions
# 9. Module 9: NumPy Arrays
# 10. Module 10: Pandas and Files

# %% [markdown]
# The primary language we will learn in this course **Python**

# %% [markdown]
# I am using *Anaconda* and *Jupyter Notebook* to create and edit this `.ipynb` file.

# %% [markdown]
# Today I worked on `setting up my GitHub repository and creating my Jupyter Notebook`.

# %%
![image](
